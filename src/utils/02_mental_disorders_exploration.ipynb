# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sea
import torch

from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.compose import ColumnTransformer

# %%
df = pd.read_csv('Dataset-Mental-Disorders.csv')
df
# Out:
#     Patient Number     Sadness    Euphoric  Exhausted Sleep dissorder  \
# 0       Patiant-01     Usually      Seldom  Sometimes       Sometimes
# 1       Patiant-02     Usually      Seldom    Usually       Sometimes
# 2       Patiant-03   Sometimes  Most-Often  Sometimes       Sometimes
# 3       Patiant-04     Usually      Seldom    Usually      Most-Often
# 4       Patiant-05     Usually     Usually  Sometimes       Sometimes
# ..             ...         ...         ...        ...             ...
# 115    Patiant-116  Most-Often      Seldom    Usually       Sometimes
# 116    Patiant-117   Sometimes   Sometimes  Sometimes          Seldom
# 117    Patiant-118     Usually   Sometimes    Usually       Sometimes
# 118    Patiant-119     Usually   Sometimes     Seldom          Seldom
# 119    Patiant-120   Sometimes     Usually     Seldom         Usually
#
#     Mood Swing Suicidal thoughts Anorxia Authority Respect Try-Explanation  \
# ...

# %%
# Manipulating the data we'll need
df = df.drop(['Patient Number'], axis=1) # -> droping ID
df.head()
# Out:
#      Sadness    Euphoric  Exhausted Sleep dissorder Mood Swing  \
# 0    Usually      Seldom  Sometimes       Sometimes        YES
# 1    Usually      Seldom    Usually       Sometimes         NO
# 2  Sometimes  Most-Often  Sometimes       Sometimes        YES
# 3    Usually      Seldom    Usually      Most-Often        YES
# 4    Usually     Usually  Sometimes       Sometimes         NO
#
#   Suicidal thoughts Anorxia Authority Respect Try-Explanation  \
# 0              YES       NO                NO             YES
# 1               YES      NO                NO              NO
# 2                NO      NO                NO             YES
# 3               YES     YES                NO             YES
# 4                NO      NO                NO              NO
#
#   Aggressive Response Ignore & Move-On Nervous Break-down Admit Mistakes  \
# 0                  NO               NO                YES            YES
# ...

# %%
y = df.iloc[:, 4:14] # Searching for only bolean values
y.head()
# Out:
#   Mood Swing Suicidal thoughts Anorxia Authority Respect Try-Explanation  \
# 0        YES              YES       NO                NO             YES
# 1         NO               YES      NO                NO              NO
# 2        YES                NO      NO                NO             YES
# 3        YES               YES     YES                NO             YES
# 4         NO                NO      NO                NO              NO
#
#   Aggressive Response Ignore & Move-On Nervous Break-down Admit Mistakes  \
# 0                  NO               NO                YES            YES
# 1                  NO               NO                 NO             NO
# 2                 YES               NO                YES            YES
# 3                  NO               NO                 NO             NO
# 4                  NO               NO                YES            YES
#
#   Overthinking
# 0          YES
# 1           NO
# 2           NO
# 3           NO
# ...

# %%
df.head() # See, the colluns 4:13
# Out:
#      Sadness    Euphoric  Exhausted Sleep dissorder Mood Swing  \
# 0    Usually      Seldom  Sometimes       Sometimes        YES
# 1    Usually      Seldom    Usually       Sometimes         NO
# 2  Sometimes  Most-Often  Sometimes       Sometimes        YES
# 3    Usually      Seldom    Usually      Most-Often        YES
# 4    Usually     Usually  Sometimes       Sometimes         NO
#
#   Suicidal thoughts Anorxia Authority Respect Try-Explanation  \
# 0              YES       NO                NO             YES
# 1               YES      NO                NO              NO
# 2                NO      NO                NO             YES
# 3               YES     YES                NO             YES
# 4                NO      NO                NO              NO
#
#   Aggressive Response Ignore & Move-On Nervous Break-down Admit Mistakes  \
# 0                  NO               NO                YES            YES
# ...

# %%
string_df = df.iloc[:, 14:17]
string_df.head()
# Strings to manipulate
# Out:
#   Sexual Activity Concentration  Optimisim
# 0       3 From 10     3 From 10  4 From 10
# 1       4 From 10     2 From 10  5 From 10
# 2       6 From 10     5 From 10  7 From 10
# 3       3 From 10     2 From 10  2 From 10
# 4       5 From 10     5 From 10  6 From 10

# %%
y = pd.DataFrame(df.iloc[:,-1])

y["Expert Diagnose"].unique() # array(['Bipolar Type-2', 'Depression', 'Bipolar Type-1', 'Normal']

y = pd.get_dummies(y,prefix=['Expert Diagnose'],
                   columns=['Expert Diagnose'],
                   drop_first=False)

# %%
df['Sexual Activity'] = df['Sexual Activity'].str.split().str[0]
df['Concentration'] = df['Concentration'].str.split().str[0]
df['Optimisim'] = df['Optimisim'].str.split().str[0]
df.head()

for x in df['Sexual Activity']:
    x = int(x)

for x in df['Concentration']:
    x = int(x)

for x in df['Optimisim']:
    x = int(x)

# %%
df = df.drop(['Expert Diagnose'], axis=1)
df = df.join(y, how='outer')

need_encode = df.iloc[:, 0:14]
need_encode = need_encode.apply(LabelEncoder().fit_transform)

# %%
need_encode.iloc[:, 4:] = need_encode.iloc[:, 4:].astype(bool)

# %%
need_encode
# Out:
#      Sadness  Euphoric  Exhausted  Sleep dissorder  Mood Swing  \
# 0          3         1          2                2        True
# 1          3         1          3                2       False
# 2          2         0          2                2        True
# 3          3         1          3                0        True
# 4          3         3          2                2       False
# ..       ...       ...        ...              ...         ...
# 115        0         1          3                2       False
# 116        2         2          2                1        True
# 117        3         2          3                2        True
# 118        3         2          1                1       False
# 119        2         3          1                3       False
#
#      Suicidal thoughts  Anorxia  Authority Respect  Try-Explanation  \
# 0                 True    False              False             True
# 1                 True    False              False            False
# ...

# %%
df.iloc[:,0:14] = need_encode
df.to_csv('dataset-mental-disorders-normalized', sep=',', index=False, encoding='utf-8')
